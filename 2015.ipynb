# %%
# загрузка пакетов: инструменты --------------------------------------------
#  работа с массивами
import numpy as np
#  фреймы данных
import pandas as pd
#  графики
import matplotlib as mpl
#  стили и шаблоны графиков на основе matplotlib
import seaborn as sns
# перекодировка категориальных переменных
from sklearn.preprocessing import LabelEncoder
#  тест Шапиро-Уилка на нормальность распределения
from scipy.stats import shapiro
#  для таймера
import time

# загрузка пакетов: модели -------------------------------------------------
#  линейные модели
import sklearn.linear_model as skl_lm
#  расчёт MSE
from sklearn.metrics import mean_squared_error
#  кросс-валидация
from sklearn.model_selection import train_test_split, LeaveOneOut
from sklearn.model_selection import KFold, cross_val_score
#  полиномиальные модели
from sklearn.preprocessing import PolynomialFeatures

plt = mpl.pyplot
mpl.style.use('seaborn-whitegrid')
sns.set_palette("Set2")

# with open(r'C:\Users\MKN\Desktop\graf2015.csv') as file1:
#     print(file1.read().replace('	', ','))

# читаем таблицу из файла .csv во фрейм
# fileURL = 'https://raw.githubusercontent.com/ania607/ML/main/data/Boston_for_lab.csv'
fileURL = r'C:\Users\MKN\Desktop\charts\2015.csv'
with open(fileURL) as file1:
    print(file1.read())
DF = pd.read_csv(fileURL)

# # матричный график разброса с линиями регрессии
# sns.pairplot(DF[['Trade_turnover', 'Cash_income', 'Consumer_price_index', 'Turnover_of_networks_in_total_volume', 'Retail_spaces_of_modern_formats']])
# plt.show()
#
# print(1)
# sns.pairplot(DF[['Trade_turnover', 'Incomes_below_pm', 'Unemployment_rate', 'Urban_population']])
# plt.show()
# Out:
# "Trade_turnover","Cash_income","Consumer_price_index","Turnover_of_networks_in_total_volume","Retail_spaces_of_modern_formats","Incomes_below_pm","Unemployment_rate","Urban_population"
# 237737,38832,103.79,26.3,280.6,8.3,3.5,81.8
# 187811,31253,104.62,41.8,111.7,16.2,4.7,84.1
# 185238,25317,104.11,23.8,157.6,13.9,6.6,62.9
# 155172,22544,104.82,5.8,51.4,11,11.1,49.1
# 164339,26100,103.67,23.5,212,13,4.8,71.5
# 202089,32726,103.88,24.8,246.8,18.8,6.2,80.9
# 141859,23535,103.2,25.7,211.2,24.8,7.7,72.7
# 191617,35019,103.12,11.9,67.7,18.9,6.3,75.4

# %%
corr_mat = DF[['Trade_turnover', 'Cash_income', 'Consumer_price_index', 'Turnover_of_networks_in_total_volume', 'Retail_spaces_of_modern_formats', 'Incomes_below_pm', 'Unemployment_rate', 'Urban_population']].corr()
corr_mat.style.background_gradient().set_precision(3)
# corr_mat.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row0_col0,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row1_col1,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row2_col2,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row3_col3,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row4_col4,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row5_col5,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row6_col6,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row7_col7{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row0_col1,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row1_col0{
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row0_col2{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row0_col3{
#             background-color:  #589ec8;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row0_col4{
#             background-color:  #358fc0;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row0_col5{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row0_col6{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row0_col7{
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row1_col2{
#             background-color:  #e0dded;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row1_col3,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row6_col2{
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row1_col4{
#             background-color:  #529bc7;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row1_col5{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row1_col6{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row1_col7{
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row2_col0{
#             background-color:  #9fbad9;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row2_col1{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row2_col3{
#             background-color:  #83afd3;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row2_col4{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row2_col5,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row5_col2,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row6_col0,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row6_col1,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row6_col3,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row6_col4,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row6_col7,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row7_col6{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row2_col6{
#             background-color:  #3790c0;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row2_col7{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row3_col0,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row3_col1{
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row3_col2{
#             background-color:  #99b8d8;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row3_col4,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row4_col0{
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row3_col5{
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row3_col6{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row3_col7,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row7_col1{
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row4_col1{
#             background-color:  #4496c3;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row4_col2,#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row5_col0{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row4_col3{
#             background-color:  #2786bb;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row4_col5{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row4_col6{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row4_col7{
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row5_col1{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row5_col3{
#             background-color:  #76aad0;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row5_col4{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row5_col6{
#             background-color:  #60a1ca;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row5_col7{
#             background-color:  #4697c4;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row6_col5{
#             background-color:  #88b1d4;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row7_col0{
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row7_col2{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row7_col3{
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row7_col4{
#             background-color:  #197db7;
#             color:  #000000;
#         }#T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row7_col5{
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }</style><table id="T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Trade_turnover</th>        <th class="col_heading level0 col1" >Cash_income</th>        <th class="col_heading level0 col2" >Consumer_price_index</th>        <th class="col_heading level0 col3" >Turnover_of_networks_in_total_volume</th>        <th class="col_heading level0 col4" >Retail_spaces_of_modern_formats</th>        <th class="col_heading level0 col5" >Incomes_below_pm</th>        <th class="col_heading level0 col6" >Unemployment_rate</th>        <th class="col_heading level0 col7" >Urban_population</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834level0_row0" class="row_heading level0 row0" >Trade_turnover</th>
#                         <td id="T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row0_col1" class="data row0 col1" >0.906</td>
#                         <td id="T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row0_col2" class="data row0 col2" >-0.013</td>
#                         <td id="T_b31c7fb4_69c7_11ed_baad_e4aaea5c9834row0_col3" class="data row0 col3" >0.255</td>
#                         <td id="T_b31c7f

# %%
# df = corr_mat
# df = df.where(np.triu(np.ones(df.shape), k=1).astype(bool))
# df = df.stack().reset_index()
# df.columns = ['Показатель_1', 'Показатель_2', 'Корреляция']
# t_stat = np.sqrt((len(DF.index) - 2) / (1 - df.Корреляция.values ** 2))
# print(t_stat)
# df['P_значение'] = 2*(1 - t.cdf(abs(t_stat), len(DF.index) - 2))
# df.loc[df['P_значение'] < 0.05].sort_values('Корреляция')
from scipy.stats import t
df = corr_mat
df = df.where(np.triu(np.ones(df.shape), k=1).astype(bool))
df = df.stack().reset_index()
df.columns = ['Показатель_1', 'Показатель_2', 'Корреляция']
t_stat = np.sqrt((len(DF.index) - 2) / (1 - df.Корреляция.values ** 2))
df['P_значение'] = 2*(1 - t.cdf(abs(t_stat), len(DF.index) - 2))
df.loc[df['P_значение'] < 0.05]
# Out:
#                             Показатель_1  \
# 0                         Trade_turnover
# 1                         Trade_turnover
# 2                         Trade_turnover
# 3                         Trade_turnover
# 4                         Trade_turnover
# 5                         Trade_turnover
# 6                         Trade_turnover
# 7                            Cash_income
# 8                            Cash_income
# 9                            Cash_income
# 10                           Cash_income
# 11                           Cash_income
# 12                           Cash_income
# 13                  Consumer_price_index
# 14                  Consumer_price_index
# 15                  Consumer_price_index
# 16                  Consumer_price_index
# 17                  Consumer_price_index
# 18  Turnover_of_networks_in_total_volume
# 19  Turnover_of_networks_in_total_volume
# 20  Turnover_of_networks_in_total_volume
# 21  Turnover_of_networks_in_total_volume
# 22       Retail_spaces_of_modern_formats
# 23       Retail_spaces_of_modern_formats
# 24       Retail_spaces_of_modern_formats
# 25                      Incomes_below_pm
# 26                      Incomes_below_pm
# 27                     Unemployment_rate
#
#                             Показатель_2  Корреляция  P_значение
# 0                            Cash_income    0.906248    0.001157
# 1                   Consumer_price_index   -0.013405    0.049810
# 2   Turnover_of_networks_in_total_volume    0.255139    0.044479
# 3        Retail_spaces_of_modern_formats    0.405491    0.036552
# 4                       Incomes_below_pm   -0.469411    0.032247
# 5                      Unemployment_rate   -0.668906    0.016506
# 6                       Urban_population    0.572349    0.024410
# 7                   Consumer_price_index   -0.257573    0.044378
# 8   Turnover_of_networks_in_total_volume    0.242425    0.044994
# 9        Retail_spaces_of_modern_formats    0.316021    0.041668
# 10                      Incomes_below_pm   -0.210995    0.046158
# 11                     Unemployment_rate   -0.699547    0.014008
# 12                      Urban_population    0.741557    0.010692
# 13  Turnover_of_networks_in_total_volume    0.091434    0.049133
# 14       Retail_spaces_of_modern_formats   -0.352857    0.039699
# 15                      Incomes_below_pm   -0.534939    0.027364
# 16                     Unemployment_rate    0.304683    0.042234
# 17                      Urban_population   -0.377182    0.038292
# 18       Retail_spaces_of_modern_formats    0.430562    0.034923
# 19                      Incomes_below_pm    0.148200    0.048010
# 20                     Unemployment_rate   -0.685940    0.015112
# 21                      Urban_population    0.724602    0.012010
# 22                      Incomes_below_pm   -0.031718    0.049742
# 23                     Unemployment_rate   -0.585557    0.023346
# 24                      Urban_population    0.520703    0.028459
# 25                     Unemployment_rate    0.157529    0.047776
# 26                      Urban_population    0.245739    0.044862
# 27                      Urban_population   -0.842931    0.003880

# %% [markdown]
# # Источники
#
# 1. *James G., Witten D., Hastie T. and Tibshirani R.*  An Introduction to Statistical Learning with Applications in R. URL: [http://www-bcf.usc.edu/~gareth/ISL/ISLR%20First%20Printing.pdf](https://drive.google.com/file/d/15PdWDMf9hkfP8mrCzql_cNiX2eckLDRw/view?usp=sharing)
# 1. Рашка С. Python и машинное обучение: крайне необходимое пособие по новейшей предсказательной аналитике, обязательное для более глубокого понимания методологии машинного обучения / пер. с англ. А.В. Логунова. – М.: ДМК Пресс, 2017. – 418 с.: ил.
# 1. Interpreting Log Transformations in a Linear Model / virginia.edu. URL: <https://data.library.virginia.edu/interpreting-log-transformations-in-a-linear-model/>
# 1. Python Timer Functions: Three Ways to Monitor Your Code / realpython.com. URL: <https://realpython.com/python-timer/>
