# %%
# загрузка пакетов: инструменты --------------------------------------------
#  работа с массивами
import numpy as np
#  фреймы данных
import pandas as pd
#  графики
import matplotlib as mpl
#  стили и шаблоны графиков на основе matplotlib
import seaborn as sns
# перекодировка категориальных переменных
from sklearn.preprocessing import LabelEncoder
#  тест Шапиро-Уилка на нормальность распределения
from scipy.stats import shapiro
#  для таймера
import time

# загрузка пакетов: модели -------------------------------------------------
#  линейные модели
import sklearn.linear_model as skl_lm
#  расчёт MSE
from sklearn.metrics import mean_squared_error
#  кросс-валидация
from sklearn.model_selection import train_test_split, LeaveOneOut
from sklearn.model_selection import KFold, cross_val_score
#  полиномиальные модели
from sklearn.preprocessing import PolynomialFeatures

plt = mpl.pyplot
mpl.style.use('seaborn-whitegrid')
sns.set_palette("Set2")

# with open(r'C:\Users\MKN\Desktop\graf2015.csv') as file1:
#     print(file1.read().replace('	', ','))

# читаем таблицу из файла .csv во фрейм
# fileURL = 'https://raw.githubusercontent.com/ania607/ML/main/data/Boston_for_lab.csv'
fileURL = r'C:\Users\MKN\Desktop\charts\2013.csv'
with open(fileURL) as file1:
    print(file1.read())
DF = pd.read_csv(fileURL)

# # матричный график разброса с линиями регрессии
# sns.pairplot(DF[['Trade_turnover', 'Cash_income', 'Consumer_price_index', 'Turnover_of_networks_in_total_volume', 'Retail_spaces_of_modern_formats']])
# plt.show()
#
# print(1)
# sns.pairplot(DF[['Trade_turnover', 'Incomes_below_pm', 'Unemployment_rate', 'Urban_population']])
# plt.show()
# Out:
# "Trade_turnover","Cash_income","Consumer_price_index","Turnover_of_networks_in_total_volume","Retail_spaces_of_modern_formats","Incomes_below_pm","Unemployment_rate","Urban_population"
# 207394,33499,100.92,23.2,222,7.5,3.3,81.7
# 156056,25490,101.19,36.9,82.4,13.4,4.3,83.8
# 153160,21563,101.1,20.9,126.9,12,6.5,62.6
# 126431,18616,101,6.2,35.9,10.2,13,49.2
# 147131,21639,101.09,20.5,185.2,10.4,4.9,71
# 188497,28719,100.81,19.2,195.3,16.9,5.7,80.3
# 132484,20108,100.89,22.4,154.6,21,7.2,72.4
# 147891,28210,100.66,9.8,58,17.5,6.5,75.1

# %%
corr_mat = DF[['Trade_turnover', 'Cash_income', 'Consumer_price_index', 'Turnover_of_networks_in_total_volume', 'Retail_spaces_of_modern_formats', 'Incomes_below_pm', 'Unemployment_rate', 'Urban_population']].corr()
corr_mat.style.background_gradient().set_precision(3)
# corr_mat.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row0_col0,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row1_col1,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row2_col2,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row3_col3,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row4_col4,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row5_col5,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row6_col6,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row7_col7{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row0_col1,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row1_col0{
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row0_col2{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row0_col3{
#             background-color:  #4094c3;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row0_col4,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row0_col7,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row4_col0{
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row0_col5,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row4_col6{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row0_col6{
#             background-color:  #eee9f3;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row1_col2{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row1_col3{
#             background-color:  #60a1ca;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row1_col4{
#             background-color:  #2786bb;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row1_col5{
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row1_col6{
#             background-color:  #eee8f3;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row1_col7{
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row2_col0,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row5_col1{
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row2_col1{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row2_col3{
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row2_col4,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row2_col7{
#             background-color:  #a2bcda;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row2_col5,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row5_col2,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row6_col0,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row6_col1,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row6_col3,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row6_col4,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row6_col7,#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row7_col6{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row2_col6{
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row3_col0{
#             background-color:  #4496c3;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row3_col1{
#             background-color:  #65a3cb;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row3_col2{
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row3_col4{
#             background-color:  #3f93c2;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row3_col5{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row3_col6{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row3_col7{
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row4_col1{
#             background-color:  #2685bb;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row4_col2{
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row4_col3{
#             background-color:  #3790c0;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row4_col5{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row4_col7{
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row5_col0{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row5_col3{
#             background-color:  #99b8d8;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row5_col4{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row5_col6{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row5_col7{
#             background-color:  #4c99c5;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row6_col2{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row6_col5{
#             background-color:  #a7bddb;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row7_col0{
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row7_col1{
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row7_col2{
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row7_col3{
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row7_col4{
#             background-color:  #187cb6;
#             color:  #000000;
#         }#T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row7_col5{
#             background-color:  #7eadd1;
#             color:  #000000;
#         }</style><table id="T_6f9304a4_69c7_11ed_9591_e4aaea5c9834" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Trade_turnover</th>        <th class="col_heading level0 col1" >Cash_income</th>        <th class="col_heading level0 col2" >Consumer_price_index</th>        <th class="col_heading level0 col3" >Turnover_of_networks_in_total_volume</th>        <th class="col_heading level0 col4" >Retail_spaces_of_modern_formats</th>        <th class="col_heading level0 col5" >Incomes_below_pm</th>        <th class="col_heading level0 col6" >Unemployment_rate</th>        <th class="col_heading level0 col7" >Urban_population</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6f9304a4_69c7_11ed_9591_e4aaea5c9834level0_row0" class="row_heading level0 row0" >Trade_turnover</th>
#                         <td id="T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row0_col1" class="data row0 col1" >0.893</td>
#                         <td id="T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row0_col2" class="data row0 col2" >-0.167</td>
#                         <td id="T_6f9304a4_69c7_11ed_9591_e4aaea5c9834row0_col3" class="data row0 col3" >0.320</td>
#                         <td id="T_6f9304

# %%
# df = corr_mat
# df = df.where(np.triu(np.ones(df.shape), k=1).astype(bool))
# df = df.stack().reset_index()
# df.columns = ['Показатель_1', 'Показатель_2', 'Корреляция']
# t_stat = np.sqrt((len(DF.index) - 2) / (1 - df.Корреляция.values ** 2))
# print(t_stat)
# df['P_значение'] = 2*(1 - t.cdf(abs(t_stat), len(DF.index) - 2))
# df.loc[df['P_значение'] < 0.05].sort_values('Корреляция')
from scipy.stats import t
df = corr_mat
df = df.where(np.triu(np.ones(df.shape), k=1).astype(bool))
df = df.stack().reset_index()
df.columns = ['Показатель_1', 'Показатель_2', 'Корреляция']
t_stat = np.sqrt((len(DF.index) - 2) / (1 - df.Корреляция.values ** 2))
df['P_значение'] = 2*(1 - t.cdf(abs(t_stat), len(DF.index) - 2))
df.loc[df['P_значение'] < 0.05]
# Out:
#                             Показатель_1  \
# 0                         Trade_turnover
# 1                         Trade_turnover
# 2                         Trade_turnover
# 3                         Trade_turnover
# 4                         Trade_turnover
# 5                         Trade_turnover
# 6                         Trade_turnover
# 7                            Cash_income
# 8                            Cash_income
# 9                            Cash_income
# 10                           Cash_income
# 11                           Cash_income
# 12                           Cash_income
# 13                  Consumer_price_index
# 14                  Consumer_price_index
# 15                  Consumer_price_index
# 16                  Consumer_price_index
# 17                  Consumer_price_index
# 18  Turnover_of_networks_in_total_volume
# 19  Turnover_of_networks_in_total_volume
# 20  Turnover_of_networks_in_total_volume
# 21  Turnover_of_networks_in_total_volume
# 22       Retail_spaces_of_modern_formats
# 23       Retail_spaces_of_modern_formats
# 24       Retail_spaces_of_modern_formats
# 25                      Incomes_below_pm
# 26                      Incomes_below_pm
# 27                     Unemployment_rate
#
#                             Показатель_2  Корреляция  P_значение
# 0                            Cash_income    0.892736    0.001608
# 1                   Consumer_price_index   -0.166808    0.047528
# 2   Turnover_of_networks_in_total_volume    0.320278    0.041451
# 3        Retail_spaces_of_modern_formats    0.696374    0.014265
# 4                       Incomes_below_pm   -0.321767    0.041374
# 5                      Unemployment_rate   -0.678318    0.015734
# 6                       Urban_population    0.655855    0.017580
# 7                   Consumer_price_index   -0.416029    0.035877
# 8   Turnover_of_networks_in_total_volume    0.214510    0.046036
# 9        Retail_spaces_of_modern_formats    0.441421    0.034193
# 10                      Incomes_below_pm   -0.156732    0.047796
# 11                     Unemployment_rate   -0.670199    0.016400
# 12                      Urban_population    0.749287    0.010103
# 13  Turnover_of_networks_in_total_volume    0.572019    0.024437
# 14       Retail_spaces_of_modern_formats   -0.018315    0.049797
# 15                      Incomes_below_pm   -0.504788    0.029662
# 16                     Unemployment_rate   -0.071689    0.049400
# 17                      Urban_population   -0.160693    0.047693
# 18       Retail_spaces_of_modern_formats    0.352460    0.039721
# 19                      Incomes_below_pm   -0.012572    0.049812
# 20                     Unemployment_rate   -0.710661    0.013115
# 21                      Urban_population    0.672294    0.016228
# 22                      Incomes_below_pm   -0.133058    0.048362
# 23                     Unemployment_rate   -0.654335    0.017705
# 24                      Urban_population    0.506692    0.029520
# 25                     Unemployment_rate    0.059305    0.049534
# 26                      Urban_population    0.211633    0.046136
# 27                      Urban_population   -0.885872    0.001865

# %% [markdown]
# # Источники
#
# 1. *James G., Witten D., Hastie T. and Tibshirani R.*  An Introduction to Statistical Learning with Applications in R. URL: [http://www-bcf.usc.edu/~gareth/ISL/ISLR%20First%20Printing.pdf](https://drive.google.com/file/d/15PdWDMf9hkfP8mrCzql_cNiX2eckLDRw/view?usp=sharing)
# 1. Рашка С. Python и машинное обучение: крайне необходимое пособие по новейшей предсказательной аналитике, обязательное для более глубокого понимания методологии машинного обучения / пер. с англ. А.В. Логунова. – М.: ДМК Пресс, 2017. – 418 с.: ил.
# 1. Interpreting Log Transformations in a Linear Model / virginia.edu. URL: <https://data.library.virginia.edu/interpreting-log-transformations-in-a-linear-model/>
# 1. Python Timer Functions: Three Ways to Monitor Your Code / realpython.com. URL: <https://realpython.com/python-timer/>
