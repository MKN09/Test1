# %%
# загрузка пакетов: инструменты --------------------------------------------
#  работа с массивами
import numpy as np
#  фреймы данных
import pandas as pd
#  графики
import matplotlib as mpl
#  стили и шаблоны графиков на основе matplotlib
import seaborn as sns
# перекодировка категориальных переменных
from sklearn.preprocessing import LabelEncoder
#  тест Шапиро-Уилка на нормальность распределения
from scipy.stats import shapiro
#  для таймера
import time

# загрузка пакетов: модели -------------------------------------------------
#  линейные модели
import sklearn.linear_model as skl_lm
#  расчёт MSE
from sklearn.metrics import mean_squared_error
#  кросс-валидация
from sklearn.model_selection import train_test_split, LeaveOneOut
from sklearn.model_selection import KFold, cross_val_score
#  полиномиальные модели
from sklearn.preprocessing import PolynomialFeatures

plt = mpl.pyplot
mpl.style.use('seaborn-whitegrid')
sns.set_palette("Set2")

# with open(r'C:\Users\MKN\Desktop\graf2015.csv') as file1:
#     print(file1.read().replace('	', ','))

# читаем таблицу из файла .csv во фрейм
# fileURL = 'https://raw.githubusercontent.com/ania607/ML/main/data/Boston_for_lab.csv'
fileURL = r'C:\Users\MKN\Desktop\charts\2014.csv'
with open(fileURL) as file1:
    print(file1.read())
DF = pd.read_csv(fileURL)

# # матричный график разброса с линиями регрессии
# sns.pairplot(DF[['Trade_turnover', 'Cash_income', 'Consumer_price_index', 'Turnover_of_networks_in_total_volume', 'Retail_spaces_of_modern_formats']])
# plt.show()
#
# print(1)
# sns.pairplot(DF[['Trade_turnover', 'Incomes_below_pm', 'Unemployment_rate', 'Urban_population']])
# plt.show()
# Out:
# "Y","X1","X2","X3","X4","X5","X6","X7"
# 164079,24750,110.53,22.3,80.4,7.7,4,66.8
# 158501,20594,113.32,15.3,246.9,13.2,5,69.5
# 129564,19529,113.3,32.1,116.3,14.2,4.3,77.7
# 181499,24973,111.95,22.5,68.9,9.2,4.5,66.7
# 138185,19832,112.24,24.4,150.1,14.6,4.3,81.1
# 161623,24318,113.18,26,138.6,9.7,4.2,75.9
# 114959,19112,110.95,21.9,383.8,13.6,4.3,70.8
# 146850,21860,110.94,24.2,104,9.2,3.9,66.5
# 171096,24420,111.9,22.5,282.7,8.3,3.7,64.1
# 220314,34589,112.2,33.1,355.4,7.6,2.7,81.6
# 131430,19007,112.69,28.5,201.7,13.5,5.1,65.9
# 140026,21340,113.47,32.7,154.7,11,4.4,71.1
# 150008,20482,114.15,18.9,103.4,15.7,5.1,72.1
# 157556,21742,112.16,20.5,64.7,9.6,4.3,59.4
# 153135,20880,113.63,17.2,107,11.6,5.3,74.9
# 152864,21936,112.37,27.7,169,9.8,4.1,76.6
# 149623,22848,113.48,27.9,101.6,10.3,3.8,81.8
# 365089,55473,111.65,20.4,438.9,8.8,1.5,98.9
# 153651,23005,110.9,29.5,99.8,14.1,8.1,79.2
# 181937,29561,110.93,25.3,53.5,14.9,6,77.5
# 176491,28111,112.96,11.7,251.1,14.8,7.2,76.5
# 178374,66981,109.71,16.9,0,8.9,5.3,70.8
# 125014,21792,112.01,24.9,220.9,13.5,5.6,71.5
# 136627,22620,115.6,24.3,107.8,12.4,5.4,77.6
# 156780,21578,111.53,44.4,173.7,9.8,4.5,64.9
# 196946,33783,110.29,37.4,116.4,11,6.7,92.7
# 155324,22964,111,32.1,92.2,12.6,3.7,70.5
# 144799,19697,112,29.4,221.3,15.8,6.5,70.2
# 197144,33170,113.28,52.1,0,8.7,1.4,100
# 164975,22078,111.43,38,98.2,11,8.6,47
# 62779,12992,111.06,18.3,39.4,31.8,10.9,44.9
# 196892,28094,112.22,18.3,144.1,10.3,5.7,53.9
# 162393,21979,110.68,17.8,97.8,12,7.5,66.7
# 126856,19388,111.99,30.7,73.2,13.6,6.6,76.4
# 177702,22957,111.8,23.3,187.9,13.1,5.9,67.8
# 171054,23298,110.51,1.2,18.9,10.2,10.2,45.1
# 41805,14681,108.12,0,1.7,23.9,29.8,40.4
# 116477,16406,108.46,8.5,55.5,18.7,9.5,52.3
# 78422,16308,110.41,14.1,142.7,19.2,13,42.7
# 131840,19257,110.23,6.4,16.8,12.5,8.6,64
# 88310,19752,111.14,0,30.9,14.2,21.5,34.8
# 165228,20537,108.61,11.4,87,12.2,5.3,57.9
# 191935,25745,111.17,13.2,120.7,10.8,5.3,61.4
# 106277,16471,111.56,33.4,73.9,19.5,4.8,64.8
# 89808,15783,111.59,20.3,142.7,17.6,4.2,60.7
# 203038,29537,109.68,21.5,351.3,7,3.9,76.1
# 129660,20164,109.58,24.7,121.5,11.9,5.1,65.3
# 106444,16381,110.94,25.2,160.8,16.4,5,60.2
# 184849,27245,110.44,21.7,319.9,12.5,5.8,75.3
# 126231,19647,111,25.6,63.5,13.1,5.1,75.1
# 190206,27049,111.38,24.7,302.4,8.8,4.2,79.2
# 134482,20700,110.9,19.7,48.7,11.9,4.4,59.8
# 133259,18721,110.88,21.1,277.2,13.2,4.6,68
# 194188,26356,111.78,26.5,168.6,12.3,3,80.3
# 120725,17786,110.93,29.5,142.4,15,4.6,75
# 129143,20565,111.42,26.2,205.8,12.7,4.8,74.2
# 117095,18315,112.02,26.4,216.6,17.1,7,61.1
# 230949,31538,110.59,23.4,95.7,8.5,6.1,84.2
# 223265,37783,108.66,16.4,268.5,12.3,4.7,79.8
# 224038,40811,108.21,15.9,402.6,11.1,4.6,92
# 235512,62020,107.46,7,159.3,6.7,3.1,83.9
# 154226,23070,109.86,23.8,354.3,11.7,6.2,82.4
# 97474,16958,110.14,25.4,269,20.9,10.4,29
# 60063,13887,109.49,4.8,45,35.2,19.1,54
# 123176,17654,110.46,9.4,143.3,18.2,6.2,68.1
# 128376,18291,111.2,26.1,176.8,17.1,7.2,55.8
# 171796,24392,109.46,16.5,140.1,17,5,76.4
# 118287,19617,110.79,15.8,85.4,18.8,8.8,79.4
# 122765,19851,111.91,34.2,315.2,14.1,6.2,85.6
# 168581,23379,110.23,32.6,188.4,14.9,5.1,78.2
# 158990,23374,111.41,26.9,265.3,12.4,6.7,71.9
# 115052,24333,110.7,29.9,302.6,13,7.6,71.6
# 124928,19692,111.2,8.1,127.4,18.8,10,67.1
# 141496,20710,111.84,7.5,258.5,18.2,8.4,58.8
# 173477,33054,110.28,5.5,68,18,7.4,65.2
# 143851,39019,107.82,10.7,118.2,16.7,6.1,77.4
# 147683,27479,111.99,7.3,58.6,15.2,6.9,76.7
# 178673,31197,111.75,22.1,57.7,13.4,5.9,81.7
# 163781,25385,110.52,13.2,68.4,14.8,5.6,67.1
# 174694,44996,107.82,9.6,46.9,12.3,3.1,95.3
# 250253,41947,108.58,1.5,42.1,9.7,6.5,81.2
# 117276,21838,111.79,15.5,184.9,21.4,8.7,67.9
# 102795,59962,103.99,0,36.7,7.6,3.2,67.5

# %%
corr_mat = DF[["Y", "X1", "X2", "X3", "X4", "X5", "X6", "X7"
]].corr()
corr_mat.style.background_gradient().set_precision(3)
# corr_mat.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row0_col0,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row1_col1,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row2_col2,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row3_col3,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row4_col4,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row5_col5,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row6_col6,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row7_col7{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row0_col1,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row7_col0{
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row0_col2,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row2_col4{
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row0_col3{
#             background-color:  #a4bcda;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row0_col4{
#             background-color:  #84b0d3;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row0_col5,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row1_col2,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row5_col0,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row5_col1,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row6_col3,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row6_col4,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row6_col7,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row7_col6{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row0_col6{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row0_col7{
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row1_col0{
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row1_col3,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row6_col2{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row1_col4{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row1_col5,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row3_col6{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row1_col6{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row1_col7{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row2_col0{
#             background-color:  #a1bbda;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row2_col1{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row2_col3,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row3_col2,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row7_col1{
#             background-color:  #2c89bd;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row2_col5{
#             background-color:  #abbfdc;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row2_col6{
#             background-color:  #cccfe5;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row2_col7{
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row3_col0{
#             background-color:  #86b0d3;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row3_col1{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row3_col4{
#             background-color:  #97b7d7;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row3_col5{
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row3_col7{
#             background-color:  #4a98c5;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row4_col0{
#             background-color:  #4c99c5;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row4_col1{
#             background-color:  #acc0dd;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row4_col2{
#             background-color:  #a2bcda;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row4_col3{
#             background-color:  #7bacd1;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row4_col5{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row4_col6{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row4_col7{
#             background-color:  #60a1ca;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row5_col2{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row5_col3{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row5_col4{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row5_col6{
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row5_col7,#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row6_col1{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row6_col0{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row6_col5{
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row7_col2{
#             background-color:  #a8bedc;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row7_col3{
#             background-color:  #62a2cb;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row7_col4{
#             background-color:  #93b5d6;
#             color:  #000000;
#         }#T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row7_col5{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }</style><table id="T_c3e6968a_7994_11ed_93d5_e4aaea5c9834" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Y</th>        <th class="col_heading level0 col1" >X1</th>        <th class="col_heading level0 col2" >X2</th>        <th class="col_heading level0 col3" >X3</th>        <th class="col_heading level0 col4" >X4</th>        <th class="col_heading level0 col5" >X5</th>        <th class="col_heading level0 col6" >X6</th>        <th class="col_heading level0 col7" >X7</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c3e6968a_7994_11ed_93d5_e4aaea5c9834level0_row0" class="row_heading level0 row0" >Y</th>
#                         <td id="T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row0_col1" class="data row0 col1" >0.643</td>
#                         <td id="T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row0_col2" class="data row0 col2" >-0.004</td>
#                         <td id="T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row0_col3" class="data row0 col3" >0.100</td>
#                         <td id="T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row0_col4" class="data row0 col4" >0.306</td>
#                         <td id="T_c3e6968a_7994_11ed_93d5_e4aaea5c9834row0_col5" class="data row0 col5" >-0.648</td>
#                         <td id="T_c3e6968a_79

# %%
# df = corr_mat
# df = df.where(np.triu(np.ones(df.shape), k=1).astype(bool))
# df = df.stack().reset_index()
# df.columns = ['Показатель_1', 'Показатель_2', 'Корреляция']
# t_stat = np.sqrt((len(DF.index) - 2) / (1 - df.Корреляция.values ** 2))
# print(t_stat)
# df['P_значение'] = 2*(1 - t.cdf(abs(t_stat), len(DF.index) - 2))
# df.loc[df['P_значение'] < 0.05].sort_values('Корреляция')
from scipy.stats import t
df = corr_mat
df = df.where(np.triu(np.ones(df.shape), k=1).astype(bool))
df = df.stack().reset_index()
df.columns = ['Показатель_1', 'Показатель_2', 'Корреляция']
t_stat = np.sqrt((len(DF.index) - 2) / (1 - df.Корреляция.values ** 2))
df['P_значение'] = 2*(1 - t.cdf(abs(t_stat), len(DF.index) - 2))
df.loc[df['P_значение'] < 0.05]
# Out:
#    Показатель_1 Показатель_2  Корреляция    P_значение
# 0             Y           X1    0.642646  0.000000e+00
# 1             Y           X2   -0.004450  7.949197e-14
# 2             Y           X3    0.100437  6.439294e-14
# 3             Y           X4    0.306082  1.021405e-14
# 4             Y           X5   -0.648297  0.000000e+00
# 5             Y           X6   -0.536547  0.000000e+00
# 6             Y           X7    0.604616  0.000000e+00
# 7            X1           X2   -0.448195  6.661338e-16
# 8            X1           X3   -0.196952  3.508305e-14
# 9            X1           X4    0.039798  7.682743e-14
# 10           X1           X5   -0.489846  2.220446e-16
# 11           X1           X6   -0.335048  6.439294e-15
# 12           X1           X7    0.479667  2.220446e-16
# 13           X2           X3    0.492541  2.220446e-16
# 14           X2           X4    0.106965  6.283862e-14
# 15           X2           X5   -0.051433  7.527312e-14
# 16           X2           X6   -0.190488  3.708145e-14
# 17           X2           X7    0.084392  6.861178e-14
# 18           X3           X4    0.245521  2.176037e-14
# 19           X3           X5   -0.260358  1.842970e-14
# 20           X3           X6   -0.456637  4.440892e-16
# 21           X3           X7    0.327392  7.327472e-15
# 22           X4           X5   -0.182046  3.952394e-14
# 23           X4           X6   -0.286194  1.332268e-14
# 24           X4           X7    0.259580  1.842970e-14
# 25           X5           X6    0.616843  0.000000e+00
# 26           X5           X7   -0.448586  6.661338e-16
# 27           X6           X7   -0.613448  0.000000e+00

# %% [markdown]
# # Источники
#
# 1. *James G., Witten D., Hastie T. and Tibshirani R.*  An Introduction to Statistical Learning with Applications in R. URL: [http://www-bcf.usc.edu/~gareth/ISL/ISLR%20First%20Printing.pdf](https://drive.google.com/file/d/15PdWDMf9hkfP8mrCzql_cNiX2eckLDRw/view?usp=sharing)
# 1. Рашка С. Python и машинное обучение: крайне необходимое пособие по новейшей предсказательной аналитике, обязательное для более глубокого понимания методологии машинного обучения / пер. с англ. А.В. Логунова. – М.: ДМК Пресс, 2017. – 418 с.: ил.
# 1. Interpreting Log Transformations in a Linear Model / virginia.edu. URL: <https://data.library.virginia.edu/interpreting-log-transformations-in-a-linear-model/>
# 1. Python Timer Functions: Three Ways to Monitor Your Code / realpython.com. URL: <https://realpython.com/python-timer/>
