# %%
# загрузка пакетов: инструменты --------------------------------------------
#  работа с массивами
import numpy as np
#  фреймы данных
import pandas as pd
#  графики
import matplotlib as mpl
#  стили и шаблоны графиков на основе matplotlib
import seaborn as sns
# перекодировка категориальных переменных
from sklearn.preprocessing import LabelEncoder
#  тест Шапиро-Уилка на нормальность распределения
from scipy.stats import shapiro
#  для таймера
import time

# загрузка пакетов: модели -------------------------------------------------
#  линейные модели
import sklearn.linear_model as skl_lm
#  расчёт MSE
from sklearn.metrics import mean_squared_error
#  кросс-валидация
from sklearn.model_selection import train_test_split, LeaveOneOut
from sklearn.model_selection import KFold, cross_val_score
#  полиномиальные модели
from sklearn.preprocessing import PolynomialFeatures

plt = mpl.pyplot
mpl.style.use('seaborn-whitegrid')
sns.set_palette("Set2")

# with open(r'C:\Users\MKN\Desktop\graf2015.csv') as file1:
#     print(file1.read().replace('	', ','))

# читаем таблицу из файла .csv во фрейм
# fileURL = 'https://raw.githubusercontent.com/ania607/ML/main/data/Boston_for_lab.csv'
fileURL = r'C:\Users\MKN\Desktop\charts\2015.csv'
with open(fileURL) as file1:
    print(file1.read())
DF = pd.read_csv(fileURL)

# # матричный график разброса с линиями регрессии
# sns.pairplot(DF[['Trade_turnover', 'Cash_income', 'Consumer_price_index', 'Turnover_of_networks_in_total_volume', 'Retail_spaces_of_modern_formats']])
# plt.show()
#
# print(1)
# sns.pairplot(DF[['Trade_turnover', 'Incomes_below_pm', 'Unemployment_rate', 'Urban_population']])
# plt.show()
# Out:
# "Y","X1","X2","X3","X4","X5","X6","X7"
# 178097,28043,111.38,23.2,83.5,8.5,4.1,66.9
# 177048,23428,113.15,21.6,295.7,14.1,4.6,69.8
# 139408,22712,112.46,33.4,132.8,14.7,5.6,77.8
# 198814,29366,113.59,21.6,74.2,9.5,4.5,66.9
# 143349,22297,113.77,27.2,162.5,16,5.6,81.2
# 167204,27434,114.54,30.5,168.5,10.8,4.3,76.2
# 131002,21939,112.89,24.8,364.6,14.3,5.3,71.3
# 160712,25330,113.91,24.6,123,10.4,4.2,66.9
# 186603,27087,112.09,23.9,288.8,9.3,4.1,64.2
# 237152,38463,113.86,36.5,376.1,8.3,3.3,81.6
# 150709,22104,112.81,27.7,302,14.5,6.2,66.3
# 148687,23690,112.3,34.7,155.9,13,4.7,71.2
# 163628,23653,111.85,21.7,114.3,17.6,6.2,72
# 172696,24865,112.69,20.8,69.7,10.7,4.6,59.8
# 161161,23672,112.09,40.6,130.6,13,5.6,75.2
# 167802,25460,112.9,30.2,189.2,10.6,4.1,74.7
# 160850,26613,113.86,30.3,97.9,10.8,5.3,81.7
# 351448,60535,114.16,21.8,419.4,8.9,1.8,98.8
# 164576,25859,112.25,34.1,122.6,16.2,8.8,79.6
# 174886,31221,113.18,28.4,68.5,15.6,7,77.7
# 194266,31285,113.03,16,291.5,16.5,6.8,77
# 192201,72146,115.35,20.1,0,9.4,7.9,71.7
# 132285,24991,112.01,32,253.3,14.5,6.8,71.9
# 145944,25510,111.74,33.7,109.9,13.6,5.7,77.7
# 175173,25541,113.29,45.9,182.4,10.3,5.1,64.6
# 201079,36747,113.37,37.8,146.9,12.7,7.8,92.6
# 173380,25631,112.55,29.9,108.6,13.9,4.6,70.9
# 156702,21524,114.22,35.1,239.1,19,6.9,70.4
# 219750,37428,113.18,52.8,0,8.5,2.1,100
# 162621,23028,112.6,39.6,97.6,13.9,8.8,47.1
# 64025,15276,111.36,19.2,39.3,29.5,10.7,45.1
# 211644,31304,112.73,21.8,179.1,11.7,6,54.1
# 170883,23832,112.61,18.3,100.1,14.2,7.5,66.5
# 135950,22103,113.17,31.4,86.4,14.2,7.2,76.5
# 194599,25825,112.07,23.4,200.6,14.4,6.1,67.9
# 205890,26764,113.98,0.7,8,11,10.8,45.1
# 46598,15191,117.54,0,7.3,29.9,30.5,40.7
# 131108,18976,115.3,7.5,54,21.1,10.1,52.2
# 74891,17810,114.88,15.7,158.5,22.8,15.1,42.7
# 144655,21804,113.56,6.8,20.4,14.2,9.3,64.1
# 106136,22709,114.83,0,35.5,16,17.1,34.7
# 166622,21244,114.92,13.2,102.4,14.6,5.6,58.1
# 192720,27320,110.92,13.5,120.7,13,6.1,61.7
# 111526,18550,112.51,35.6,69.2,22.2,5.3,65.2
# 96377,17588,111.12,22.7,194.6,19.8,4.2,61.2
# 200999,32404,110.74,23.4,355,7.1,4,76.3
# 136441,24255,111.29,21.6,91.3,12.3,5,65.5
# 110509,18141,111.46,29.1,132.8,17.9,5,60.7
# 181373,31606,112.56,22.7,346,12.8,6.3,75.5
# 134426,21565,111.13,28.2,97.6,15.3,5.3,75.6
# 191452,30003,112.15,24.9,363.8,9.9,4.3,79.4
# 139328,22943,110.42,23.1,59.3,13.9,4.8,59.9
# 141527,21453,111.32,21.9,298.5,14.4,4.7,68.1
# 183836,27914,112.73,27.9,158,13.1,3.4,80.3
# 126139,20111,111.68,31.5,153.3,16.9,4.7,75.2
# 134072,22711,113.78,26.2,227.8,14.8,4.9,74.5
# 122152,20310,114.01,28.5,185.5,18.8,7.5,61.5
# 239283,34113,114.04,25.1,106.1,9.9,6.5,84.3
# 230504,41893,112.63,21.3,271.6,14,4.9,79.9
# 229048,46221,113.36,21.7,388.7,11.9,4.4,92.1
# 245559,67624,110.5,10.4,174.1,7.5,3.6,83.8
# 146636,24654,111.97,29.1,410.7,13.7,7,82.5
# 100956,17872,112.49,28.8,274.4,24.8,9.7,29.2
# 68576,15572,111.35,5,44.8,36.9,18.6,53.9
# 137261,19116,110.33,9.1,152.3,19.2,5.8,68.5
# 134925,20860,112.37,28.6,191.8,18,8,56
# 165372,27053,110.56,19.4,151.9,18.9,6.2,76.7
# 120490,21753,112.15,20.2,103.7,20.7,8.2,78.9
# 126178,21879,111.48,34.8,342,15.7,7.7,85.7
# 161317,25541,111.38,37.9,201.7,17.3,6.9,78.5
# 155026,25283,110.89,30.7,272.3,14.2,6.8,72.2
# 124791,26827,112.43,27.4,309.6,14.9,7.7,71.9
# 135400,22014,114.25,11.7,162.2,21.3,10.4,67.4
# 165812,23858,110.7,7.5,253.8,18.9,9.2,58.9
# 196688,37013,110.51,8.1,31.5,19.4,7.3,65.3
# 159247,42818,112.62,12.3,121.8,17.1,4.5,77.5
# 176963,31072,111.91,9.5,63,16.2,6.9,76.9
# 203200,35460,113.07,21.3,78,14.1,5.3,81.8
# 182491,28240,112.78,14.1,76.9,15.2,5.8,67.3
# 187765,50750,113.11,9.8,68.4,12.9,4.3,95.4
# 272527,47872,110.64,2.2,41,10,6.3,81.4
# 133748,23759,111.05,15.9,187.3,25.1,7.9,68.2
# 119335,63308,111.06,0,36.8,8.6,4,68.3

# %%
corr_mat = DF[["Y", "X1", "X2", "X3", "X4", "X5", "X6", "X7"
]].corr()
corr_mat.style.background_gradient().set_precision(3)
# corr_mat.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row0_col0,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row1_col1,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row2_col2,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row3_col3,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row4_col4,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row5_col5,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row6_col6,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row7_col7{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row0_col1{
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row0_col2{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row0_col3{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row0_col4{
#             background-color:  #9ebad9;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row0_col5,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row5_col0,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row5_col1,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row6_col3,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row6_col4,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row6_col7,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row7_col2,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row7_col6{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row0_col6{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row0_col7{
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row1_col0,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row6_col5{
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row1_col2,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row5_col3,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row7_col5{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row1_col3{
#             background-color:  #e2dfee;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row1_col4{
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row1_col5,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row3_col2{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row1_col6{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row1_col7{
#             background-color:  #1e80b8;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row2_col0{
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row2_col1{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row2_col3{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row2_col4{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row2_col5{
#             background-color:  #96b6d7;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row2_col6{
#             background-color:  #3d93c2;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row2_col7{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row3_col0{
#             background-color:  #89b1d4;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row3_col1{
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row3_col4{
#             background-color:  #86b0d3;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row3_col5{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row3_col6{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row3_col7{
#             background-color:  #4496c3;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row4_col0,#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row4_col7{
#             background-color:  #60a1ca;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row4_col1{
#             background-color:  #acc0dd;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row4_col2{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row4_col3{
#             background-color:  #71a8ce;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row4_col5{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row4_col6{
#             background-color:  #dfddec;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row5_col2{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row5_col4{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row5_col6{
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row5_col7{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row6_col0{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row6_col1{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row6_col2{
#             background-color:  #84b0d3;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row7_col0{
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row7_col1{
#             background-color:  #2383ba;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row7_col3{
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }#T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row7_col4{
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }</style><table id="T_0162b1c0_7995_11ed_ac18_e4aaea5c9834" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Y</th>        <th class="col_heading level0 col1" >X1</th>        <th class="col_heading level0 col2" >X2</th>        <th class="col_heading level0 col3" >X3</th>        <th class="col_heading level0 col4" >X4</th>        <th class="col_heading level0 col5" >X5</th>        <th class="col_heading level0 col6" >X6</th>        <th class="col_heading level0 col7" >X7</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0162b1c0_7995_11ed_ac18_e4aaea5c9834level0_row0" class="row_heading level0 row0" >Y</th>
#                         <td id="T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row0_col1" class="data row0 col1" >0.672</td>
#                         <td id="T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row0_col2" class="data row0 col2" >-0.014</td>
#                         <td id="T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row0_col3" class="data row0 col3" >0.059</td>
#                         <td id="T_0162b1c0_7995_11ed_ac18_e4aaea5c9834row0_col4" class="data row0 col4" >0.219</td>

# %%
# df = corr_mat
# df = df.where(np.triu(np.ones(df.shape), k=1).astype(bool))
# df = df.stack().reset_index()
# df.columns = ['Показатель_1', 'Показатель_2', 'Корреляция']
# t_stat = np.sqrt((len(DF.index) - 2) / (1 - df.Корреляция.values ** 2))
# print(t_stat)
# df['P_значение'] = 2*(1 - t.cdf(abs(t_stat), len(DF.index) - 2))
# df.loc[df['P_значение'] < 0.05].sort_values('Корреляция')
from scipy.stats import t
df = corr_mat
df = df.where(np.triu(np.ones(df.shape), k=1).astype(bool))
df = df.stack().reset_index()
df.columns = ['Показатель_1', 'Показатель_2', 'Корреляция']
t_stat = np.sqrt((len(DF.index) - 2) / (1 - df.Корреляция.values ** 2))
df['P_значение'] = 2*(1 - t.cdf(abs(t_stat), len(DF.index) - 2))
df.loc[df['P_значение'] < 0.05]
# Out:
#    Показатель_1 Показатель_2  Корреляция    P_значение
# 0             Y           X1    0.671711  0.000000e+00
# 1             Y           X2   -0.014173  7.904788e-14
# 2             Y           X3    0.058739  7.394085e-14
# 3             Y           X4    0.218948  2.864375e-14
# 4             Y           X5   -0.697428  0.000000e+00
# 5             Y           X6   -0.540291  0.000000e+00
# 6             Y           X7    0.579267  0.000000e+00
# 7            X1           X2    0.000059  7.949197e-14
# 8            X1           X3   -0.182282  3.952394e-14
# 9            X1           X4    0.014694  7.904788e-14
# 10           X1           X5   -0.537597  0.000000e+00
# 11           X1           X6   -0.337620  6.217249e-15
# 12           X1           X7    0.498409  2.220446e-16
# 13           X2           X3   -0.030469  7.793766e-14
# 14           X2           X4   -0.113921  6.061818e-14
# 15           X2           X5    0.008418  7.926992e-14
# 16           X2           X6    0.384722  2.664535e-15
# 17           X2           X7   -0.137204  5.373479e-14
# 18           X3           X4    0.294671  1.199041e-14
# 19           X3           X5   -0.257389  1.909584e-14
# 20           X3           X6   -0.424788  1.110223e-15
# 21           X3           X7    0.356439  4.440892e-15
# 22           X4           X5   -0.183095  3.930190e-14
# 23           X4           X6   -0.291469  1.243450e-14
# 24           X4           X7    0.274218  1.554312e-14
# 25           X5           X6    0.674082  0.000000e+00
# 26           X5           X7   -0.492210  2.220446e-16
# 27           X6           X7   -0.587788  0.000000e+00

# %% [markdown]
# # Источники
#
# 1. *James G., Witten D., Hastie T. and Tibshirani R.*  An Introduction to Statistical Learning with Applications in R. URL: [http://www-bcf.usc.edu/~gareth/ISL/ISLR%20First%20Printing.pdf](https://drive.google.com/file/d/15PdWDMf9hkfP8mrCzql_cNiX2eckLDRw/view?usp=sharing)
# 1. Рашка С. Python и машинное обучение: крайне необходимое пособие по новейшей предсказательной аналитике, обязательное для более глубокого понимания методологии машинного обучения / пер. с англ. А.В. Логунова. – М.: ДМК Пресс, 2017. – 418 с.: ил.
# 1. Interpreting Log Transformations in a Linear Model / virginia.edu. URL: <https://data.library.virginia.edu/interpreting-log-transformations-in-a-linear-model/>
# 1. Python Timer Functions: Three Ways to Monitor Your Code / realpython.com. URL: <https://realpython.com/python-timer/>
