# %%
# загрузка пакетов: инструменты --------------------------------------------
#  работа с массивами
import numpy as np
#  фреймы данных
import pandas as pd
#  графики
import matplotlib as mpl
#  стили и шаблоны графиков на основе matplotlib
import seaborn as sns
# перекодировка категориальных переменных
from sklearn.preprocessing import LabelEncoder
#  тест Шапиро-Уилка на нормальность распределения
from scipy.stats import shapiro
#  для таймера
import time

# загрузка пакетов: модели -------------------------------------------------
#  линейные модели
import sklearn.linear_model as skl_lm
#  расчёт MSE
from sklearn.metrics import mean_squared_error
#  кросс-валидация
from sklearn.model_selection import train_test_split, LeaveOneOut
from sklearn.model_selection import KFold, cross_val_score
#  полиномиальные модели
from sklearn.preprocessing import PolynomialFeatures

plt = mpl.pyplot
mpl.style.use('seaborn-whitegrid')
sns.set_palette("Set2")

# with open(r'C:\Users\MKN\Desktop\graf2015.csv') as file1:
#     print(file1.read().replace('	', ','))

# читаем таблицу из файла .csv во фрейм
# fileURL = 'https://raw.githubusercontent.com/ania607/ML/main/data/Boston_for_lab.csv'
fileURL = r'C:\Users\MKN\Desktop\charts\2013.csv'
with open(fileURL) as file1:
    print(file1.read())
DF = pd.read_csv(fileURL)

# # матричный график разброса с линиями регрессии
# sns.pairplot(DF[['Trade_turnover', 'Cash_income', 'Consumer_price_index', 'Turnover_of_networks_in_total_volume', 'Retail_spaces_of_modern_formats']])
# plt.show()
#
# print(1)
# sns.pairplot(DF[['Trade_turnover', 'Incomes_below_pm', 'Unemployment_rate', 'Urban_population']])
# plt.show()
# Out:
# "Y","X1","X2","X3","X4","X5","X6","X7"
# 144992,23247,106.24,22.6,70.8,7.6,4,66.6
# 138669,18707,107.15,14.4,223.5,12.6,5.2,69.3
# 116202,18058,107.5,30.7,76.8,14.1,3.8,77.6
# 158218,21683,107.08,22.3,62.8,9.4,4.7,66.3
# 121813,17754,107.38,23.4,129.3,14.4,5.2,81.1
# 144553,22243,107.6,23.3,96.7,9.4,4.5,75.9
# 104945,16968,107.43,19.7,359.7,14.2,4.9,70.5
# 130337,19436,105.88,23.2,78.9,9.6,4.6,66.5
# 151358,21957,106.25,23.2,271.2,7.9,3.7,64
# 191797,32969,107.37,33.6,326.5,7.5,2.8,81.4
# 116988,17252,107.42,27.6,179.2,13.3,5.8,65.8
# 123656,18932,108.07,27.9,107.5,12.3,4.7,71
# 134889,18470,106.17,15.7,100.6,15.7,5.2,72.5
# 139912,19685,107.16,18.8,64.5,8.2,4.6,59.1
# 133177,19268,107.2,12.5,86,11.6,5.3,74.9
# 136909,19675,107.24,23.6,95.4,9.7,4.2,78.8
# 131399,20664,107.04,27.4,100.2,10.8,4.5,81.9
# 333529,55936,106.21,20.4,328.5,8.7,1.7,98.9
# 83988,14669,106.43,25.2,12.6,21,11.5,28.9
# 54096,13559,105.41,2.8,21.9,33,19.3,53.9
# 113937,16649,105.39,8.4,137.7,17.8,6,67.7
# 118096,15896,107.03,25.7,106,17.6,8.3,55.5
# 162148,24258,104.8,15.8,104.2,15.6,5.7,76.6
# 110126,18843,105.1,18.4,98,17,8.3,79.5
# 125935,19328,106.73,31.6,198,13.9,6,85.5
# 159368,22616,105.75,30.8,156.7,14.4,5.9,77.9
# 149230,20621,106.13,24.6,252.3,12.5,6.8,71.8
# 110583,22874,106.6,27.6,316.4,13,7.6,71.2
# 116140,19074,108.28,8,67.6,16.9,10.5,66.8
# 134060,18901,107.48,8.1,239.7,17.5,8,59
# 149556,30595,105.98,6.1,84.4,16.8,7.4,64.9
# 132314,35545,106.27,10,97.4,16.7,5.7,77.1
# 128066,23759,106.25,6.3,46.3,16.3,7.1,76.6
# 156908,29213,106.34,18.9,47.5,12.5,5.7,81.5
# 145301,23036,107.69,12.6,62.6,16.2,6.1,67.1
# 153398,42228,109.01,9.8,51.9,12.2,2.9,95.8
# 228920,37791,106.51,1.4,32.7,9.9,7.2,80.8
# 108408,20413,108.52,14.6,113.9,20.9,8.3,67.9
# 108218,55625,105.24,0,36.6,7.5,3.3,66.7

# %%
corr_mat = DF[["Y", "X1", "X2", "X3", "X4", "X5", "X6", "X7"
]].corr()
corr_mat.style.background_gradient().set_precision(3)
# corr_mat.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col0,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row1_col1,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row2_col2,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row3_col3,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row4_col4,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row5_col5,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row6_col6,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row7_col7{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col1{
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col2{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col3,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row3_col2{
#             background-color:  #acc0dd;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col4{
#             background-color:  #7bacd1;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col5,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row5_col0,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row5_col1,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row6_col2,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row6_col3,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row6_col4,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row6_col7,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row7_col6{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col6,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row5_col7{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col7{
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row1_col0{
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row1_col2{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row1_col3,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row4_col6{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row1_col4,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row2_col4{
#             background-color:  #c9cee4;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row1_col5,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row3_col6{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row1_col6{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row1_col7{
#             background-color:  #2484ba;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row2_col0{
#             background-color:  #a1bbda;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row2_col1{
#             background-color:  #cacee5;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row2_col3,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row2_col5{
#             background-color:  #91b5d6;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row2_col6{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row2_col7{
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row3_col0{
#             background-color:  #88b1d4;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row3_col1{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row3_col4{
#             background-color:  #94b6d7;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row3_col5{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row3_col7,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row4_col7{
#             background-color:  #549cc7;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row4_col0{
#             background-color:  #4697c4;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row4_col1{
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row4_col2,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row5_col2{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row4_col3{
#             background-color:  #81aed2;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row4_col5{
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row5_col3{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row5_col4{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row5_col6{
#             background-color:  #1e80b8;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row6_col0,#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row7_col5{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row6_col1{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row6_col5{
#             background-color:  #167bb6;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row7_col0{
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row7_col1{
#             background-color:  #2987bc;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row7_col2{
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row7_col3{
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }#T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row7_col4{
#             background-color:  #7eadd1;
#             color:  #000000;
#         }</style><table id="T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Y</th>        <th class="col_heading level0 col1" >X1</th>        <th class="col_heading level0 col2" >X2</th>        <th class="col_heading level0 col3" >X3</th>        <th class="col_heading level0 col4" >X4</th>        <th class="col_heading level0 col5" >X5</th>        <th class="col_heading level0 col6" >X6</th>        <th class="col_heading level0 col7" >X7</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834level0_row0" class="row_heading level0 row0" >Y</th>
#                         <td id="T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col1" class="data row0 col1" >0.667</td>
#                         <td id="T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col2" class="data row0 col2" >-0.016</td>
#                         <td id="T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col3" class="data row0 col3" >0.087</td>
#                         <td id="T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col4" class="data row0 col4" >0.322</td>
#                         <td id="T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col5" class="data row0 col5" >-0.666</td>
#                         <td id="T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col6" class="data row0 col6" >-0.489</td>
#                         <td id="T_3fba3e82_7994_11ed_b3ce_e4aaea5c9834row0_col7" class

# %%
# df = corr_mat
# df = df.where(np.triu(np.ones(df.shape), k=1).astype(bool))
# df = df.stack().reset_index()
# df.columns = ['Показатель_1', 'Показатель_2', 'Корреляция']
# t_stat = np.sqrt((len(DF.index) - 2) / (1 - df.Корреляция.values ** 2))
# print(t_stat)
# df['P_значение'] = 2*(1 - t.cdf(abs(t_stat), len(DF.index) - 2))
# df.loc[df['P_значение'] < 0.05].sort_values('Корреляция')
from scipy.stats import t
df = corr_mat
df = df.where(np.triu(np.ones(df.shape), k=1).astype(bool))
df = df.stack().reset_index()
df.columns = ['Показатель_1', 'Показатель_2', 'Корреляция']
t_stat = np.sqrt((len(DF.index) - 2) / (1 - df.Корреляция.values ** 2))
df['P_значение'] = 2*(1 - t.cdf(abs(t_stat), len(DF.index) - 2))
df.loc[df['P_значение'] < 0.05]
# Out:
#    Показатель_1 Показатель_2  Корреляция    P_значение
# 0             Y           X1    0.667219  0.000000e+00
# 1             Y           X2   -0.015718  7.904788e-14
# 2             Y           X3    0.086762  6.816769e-14
# 3             Y           X4    0.321991  7.993606e-15
# 4             Y           X5   -0.666276  0.000000e+00
# 5             Y           X6   -0.489389  2.220446e-16
# 6             Y           X7    0.614710  0.000000e+00
# 7            X1           X2   -0.104795  6.328271e-14
# 8            X1           X3   -0.190328  3.708145e-14
# 9            X1           X4    0.044947  7.616130e-14
# 10           X1           X5   -0.504657  0.000000e+00
# 11           X1           X6   -0.273784  1.554312e-14
# 12           X1           X7    0.483090  2.220446e-16
# 13           X2           X3    0.184252  3.885781e-14
# 14           X2           X4    0.046429  7.593925e-14
# 15           X2           X5    0.045662  7.616130e-14
# 16           X2           X6   -0.270473  1.620926e-14
# 17           X2           X7    0.110595  6.172840e-14
# 18           X3           X4    0.242482  2.264855e-14
# 19           X3           X5   -0.232569  2.509104e-14
# 20           X3           X6   -0.424063  1.110223e-15
# 21           X3           X7    0.313018  9.103829e-15
# 22           X4           X5   -0.257501  1.909584e-14
# 23           X4           X6   -0.309598  9.547918e-15
# 24           X4           X7    0.313346  9.103829e-15
# 25           X5           X6    0.506514  0.000000e+00
# 26           X5           X7   -0.489637  2.220446e-16
# 27           X6           X7   -0.573087  0.000000e+00

# %% [markdown]
# # Источники
#
# 1. *James G., Witten D., Hastie T. and Tibshirani R.*  An Introduction to Statistical Learning with Applications in R. URL: [http://www-bcf.usc.edu/~gareth/ISL/ISLR%20First%20Printing.pdf](https://drive.google.com/file/d/15PdWDMf9hkfP8mrCzql_cNiX2eckLDRw/view?usp=sharing)
# 1. Рашка С. Python и машинное обучение: крайне необходимое пособие по новейшей предсказательной аналитике, обязательное для более глубокого понимания методологии машинного обучения / пер. с англ. А.В. Логунова. – М.: ДМК Пресс, 2017. – 418 с.: ил.
# 1. Interpreting Log Transformations in a Linear Model / virginia.edu. URL: <https://data.library.virginia.edu/interpreting-log-transformations-in-a-linear-model/>
# 1. Python Timer Functions: Three Ways to Monitor Your Code / realpython.com. URL: <https://realpython.com/python-timer/>
